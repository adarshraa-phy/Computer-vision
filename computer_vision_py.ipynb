# %% [markdown]
# <a href="https://colab.research.google.com/github/adarshraa-phy/Computer-vision/blob/main/computer_vision_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt

#Read an image
image=cv2.imread("/content/MESSI.jpg")
image_rgb=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

#convert to grayscale
gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

#apply gaussian blur
blur=cv2.GaussianBlur(gray,(5,5),0)

#edge detection
edges=cv2.Canny(gray,100,200)

#show result
titles=['orginal','gray','blurr',"edges"]
images=[image_rgb,gray,blur,edges]
plt.figure(figsize=(10,8))
for i in range(4):
  plt.subplot(2,2,i+1)
  cmap='gray' if i>0 else None
  plt.imshow(images[i],cmap=cmap)
  plt.title(titles[i])
  plt.axis("off")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

#load pretrained face detecter (Haar cascade)
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

#read image
img=cv2.imread("/content/MESSI.jpg")
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

#detect faces
faces=face_cascade.detectMultiScale(gray,1.3,5)

#draw rectangles
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Show result
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title("Face Detection")
plt.axis('off')
plt.show()
